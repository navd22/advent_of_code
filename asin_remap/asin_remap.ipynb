# %%
import pandas as pd
import numpy as np
# %matplotlib inline

df = pd.read_excel (r'histogram_input.xlsx')
print (df)
# Out:
#               MCID  Contacts
# 0       4919502902         1
# 1      14267892415         1
# 2       5608591502         1
# 3      14144593202         1
# 4       5682826502         1
# ...            ...       ...
# 2835  193694570502       830
# 2836  142679240002       871
# 2837  264025741902       953
# 2838   85354716502      1089
# 2839  193508724702      1400
#
# [2840 rows x 2 columns]

# %%
df.groupby('Contacts').count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Contacts'>

# %%
df.hist(bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'MCID'}>,
#         <AxesSubplot:title={'center':'Contacts'}>]], dtype=object)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas

df = pd.read_excel (r'multiple_histograms.xlsx')
np.random.seed(0)

df['bucket 1'].hist()
#df['bucket 2'].hist()
# Out:
# <AxesSubplot:>
